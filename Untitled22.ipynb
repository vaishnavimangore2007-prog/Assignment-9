# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavimangore2007-prog/Assignment-9/blob/main/Untitled22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install SimPy (Run only once in terminal)
# pip install simpy

import simpy

# Example 1
print("SimPy installed successfully!")

def process(env):
    print("Process starts at", env.now)
    yield env.timeout(5)
    print("Process ends at", env.now)

env = simpy.Environment()
env.process(process(env))
env.run()

print("-" * 30)

# Example 2
def customer(env):
    print("Customer arrives at", env.now)
    yield env.timeout(3)
    print("Customer served at", env.now)

env = simpy.Environment()
env.process(customer(env))
env.run()

print("-" * 30)

# Example 3
def process1(env):
    yield env.timeout(2)
    print("Process 1 completed at", env.now)

def process2(env):
    yield env.timeout(4)
    print("Process 2 completed at", env.now)

env = simpy.Environment()
env.process(process1(env))
env.process(process2(env))
env.run()

print("-" * 30)

# Example 4 - Average Waiting Time
wait_times = [2, 4, 3, 1]

average = sum(wait_times) / len(wait_times)

print("Average waiting time:", average)
# Out:
# SimPy installed successfully!
# Process starts at 0
# Process ends at 5
# ------------------------------
# Customer arrives at 0
# Customer served at 3
# ------------------------------
# Process 1 completed at 2
# Process 2 completed at 4
# ------------------------------
# Average waiting time: 2.5
